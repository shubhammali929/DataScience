# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([3,11,16,23,27,34,48,55,56,67])
y = np.array([13,23,34,49,47,61,69,78,84,89])

# %%
plt.plot(x,y)

# %%
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x,y)

# %%
z = np.array([87,77,75,71,54,33,21,23,19,10])

# %%
plt.grid()
plt.plot(x,z, marker='o', color='red', ls=':',lw=3,mfc='blue') #ls->(line style) lw->l(ine width) mfc-> (marker face color)

# %%
plt.plot(x,y, label='2023', color='blue')
plt.plot(x,z, label='2023', color='green')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.plot(x,y)

# %%
plt.grid()
plt.scatter(x,y)

# %%
java = np.array([34,45,56,67,78,89,100,29])
python = np.array([23,34,45,56,67,78,99,45])

# %%
plt.title('Student Groups')
plt.xlabel('Java Marks')
plt.ylabel('Python Marks')
plt.grid()
plt.plot(java,python)
plt.plot(x,z, marker='o', color='red',)
plt.plot(java, label='2023', color='blue')
plt.plot(python, label='2023', color='green')

# %%
cols = [1,2,1,3,2,1,2,3]

# %%
plt.scatter(java,python,c=cols)

# %%
percentage=[89.34,45.34,76.45,65.90,11.34,71.90]
subject = ['python','php','DSA','java','C','OOP']

# %%
plt.title('Result Analysis')
plt.xlabel('subject')
plt.ylabel('% of passing')
plt.grid()
plt.bar(subject, percentage, color='brown')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title('Result Analysis')
plt.ylabel('subject')
plt.xlabel('% of passing')
plt.grid()
plt.barh(subject, percentage, color='brown')
# Out:
# <BarContainer object of 6 artists>

# %%
enrollment = [167,67,89,106,48,99]
courses = ['python','php','DSA','Java','C','OPPS']

# %%
plt.figure(figsize=(10,10))
plt.pie(enrollment, labels=courses, autopct='%2.2f%%');

# %%
import pandas as pd

# %%
df = pd.read_csv('imcc.csv')

# %%
plt.figure(figsize=(16,9))
plt.barh(df['name'],df['sgpa'])
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### HISTOGRAM

# %%
marks = np.array([56,67,72,93,75,45,26,58,65,61,68,67])

# %%
plt.xlabel('Range of Marks')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks,color='red',bins=range(0,101,10));

# %% [markdown]
# ### BOX PLOT

# %%
plt.boxplot(marks);

# %%
plt.boxplot(df['sgpa']);

# %% [markdown]
# ###  LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
a = np.arange(1,10,0.25)

# %%
a
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
b = a*1.56+32.07

# %%
b
# Out:
# array([33.63, 34.02, 34.41, 34.8 , 35.19, 35.58, 35.97, 36.36, 36.75,
#        37.14, 37.53, 37.92, 38.31, 38.7 , 39.09, 39.48, 39.87, 40.26,
#        40.65, 41.04, 41.43, 41.82, 42.21, 42.6 , 42.99, 43.38, 43.77,
#        44.16, 44.55, 44.94, 45.33, 45.72, 46.11, 46.5 , 46.89, 47.28])

# %%
plt.plot(a,b)

# %% [markdown]
# ### separate input and output variables

# %%
# y is always variable 
x = df['YearsExperience'].values #values -> to convert series into array format
y = df['Salary'] # here y is in series format

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
x=x.reshape(30,1)
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# ###  import the class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### create the object of linear regression

# %%
regressor = LinearRegression()

# %% [markdown]
# ### Train the algrithm with data

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[25]])
# Out:
# array([262041.25823505])

# %%
regressor.predict([[5]])
# Out:
# array([73042.01180594])

# %%
regressor.predict([[15000]])    ##--------------->GIVES WRONG OUTPUT<--------------------------
# Out:
# array([1.41775227e+08])
