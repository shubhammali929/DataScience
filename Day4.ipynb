# %% [markdown]
# ### MULTIPLE REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mtcars.csv')

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df.corrwith(df['mpg'])
# Out:
# mpg     1.000000
# cyl    -0.852162
# disp   -0.847551
# hp     -0.776168
# drat    0.681172
# wt     -0.867659
# qsec    0.418684
# vs      0.664039
# am      0.599832
# gear    0.480285
# carb   -0.550925
# dtype: float64

# %%
salary = pd.read_csv('Salary_Data.csv')

# %%
salary.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# ### seperate the input and output

# %%
x = df[['disp','hp','wt']]
y = df['mpg']

# %%
x
# Out:
#      disp   hp     wt
# 0   160.0  110  2.620
# 1   160.0  110  2.875
# 2   108.0   93  2.320
# 3   258.0  110  3.215
# 4   360.0  175  3.440
# 5   225.0  105  3.460
# 6   360.0  245  3.570
# 7   146.7   62  3.190
# 8   140.8   95  3.150
# 9   167.6  123  3.440
# 10  167.6  123  3.440
# 11  275.8  180  4.070
# 12  275.8  180  3.730
# 13  275.8  180  3.780
# 14  472.0  205  5.250
# 15  460.0  215  5.424
# 16  440.0  230  5.345
# 17   78.7   66  2.200
# 18   75.7   52  1.615
# 19   71.1   65  1.835
# 20  120.1   97  2.465
# 21  318.0  150  3.520
# 22  304.0  150  3.435
# 23  350.0  245  3.840
# 24  400.0  175  3.845
# 25   79.0   66  1.935
# 26  120.3   91  2.140
# 27   95.1  113  1.513
# 28  351.0  264  3.170
# 29  145.0  175  2.770
# 30  301.0  335  3.570
# 31  121.0  109  2.780

# %%
y
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %% [markdown]
# # import the class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### create the object

# %%
reg = LinearRegression()

# %% [markdown]
# ### train the model

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
reg.predict([[170,80,3]])
# Out:
# C:\Users\Shubham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.05101791])

# %%
reg.score(x,y) #Accuracy of the ai (min 80 required)
# Out:
# 0.8268361424946447

# %% [markdown]
# ### visualize

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.plot(df['disp'],y)

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.scatter(df['disp'],y)

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.xlabel("Milage")
plt.ylabel("disp")
plt.scatter(df['disp'],y)
plt.subplot(2,2,2)
plt.xlabel("Milage")
plt.ylabel("horse power")
plt.scatter(df['hp'],y)
plt.subplot(2,2,3)
plt.scatter(df['wt'],y)
plt.xlabel("Milage")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
## Decision Tree Classification

# %%
### Import the dataset

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.shape
# Out:
# (400, 5)

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
### seperate input and output variables

# %%
x = df[['Age','EstimatedSalary']]
y = df['Purchased']

# %%
x
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
y.value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
reg = LinearRegression()
reg.fit(x,y)
reg.predict([[45,40000]])
# Out:
# C:\Users\Shubham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.43872875])

# %% [markdown]
# ### Visualize the data

# %%
plotplt.title('Purchace Data')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x['Age'], x['EstimatedSalary'])

# %%
plt.title('Purchace Data')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x['Age'], x['EstimatedSalary'], c=y)

# %% [markdown]
# ### import the class

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### create the object

# %%
classfier = DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ### train the model

# %%
classfier.fit(x,y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ### plot the tree

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(64,36))
plot_tree(classfier, fontsize=15,feature_names=['age','sal'],
         class_names=['y','n'],filled=True, rounded=True);

# %%
### predict on new data

# %%
new = pd.DataFrame({
    'Age':[23,45,54,67],
    'EstimatedSalary':[45000,89000,23000,134000]
})

# %%
new
# Out:
#    Age  EstimatedSalary
# 0   23            45000
# 1   45            89000
# 2   54            23000
# 3   67           134000

# %%
classfier.predict(new)
# Out:
# array([0, 0, 1, 1], dtype=int64)

# %% [markdown]
# # Naives Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
### create  the object

# %%
classifier = GaussianNB()

# %%
### train the model

# %%
classifier.fit(x,y)
# Out:
# GaussianNB()

# %%
classifier.predict([[34,999999]])
# Out:
# C:\Users\Shubham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
classfier.predict(new)
# Out:
# array([0, 0, 1, 1], dtype=int64)

# %%
new
# Out:
#    Age  EstimatedSalary
# 0   23            45000
# 1   45            89000
# 2   54            23000
# 3   67           134000

# %%
classifier.predict_proba(new)
# Out:
# array([[9.87869132e-01, 1.21308684e-02],
#        [3.50234752e-01, 6.49765248e-01],
#        [1.25743407e-01, 8.74256593e-01],
#        [1.33563595e-04, 9.99866436e-01]])
